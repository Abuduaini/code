# %% [markdown]
# # input and pretreatment of spectral data
# ## Input the data

# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
import csv
import scipy.io as scio
import import_ipynb
import colour

# %%
from spectrum_pretreatment import  total_pretreatment,WL,read_mean_dark   #主要包含各类预处理命令
# Out:
# importing Jupyter notebook from spectrum_pretreatment.ipynb

# %%
plt.rcParams['font.sans-serif']=['simhei']  #显示中文
plt.rcParams['axes.unicode_minus']=False    #显示负号

# %%
fpath = 'F:/code/'
screen_path = fpath + 'screendata/'
picture_path = fpath + 'picture/'

# %% [markdown]
# ### Add spectrum in phone screen eye protection mode and standard mode

# %%
phone1_standard = 'phone1 standard.csv'
phone1_eyeprotect = 'phone1 eyeprotect.csv'

phone2_standard = 'phone2 standard.csv'
phone2_eyeprotect = 'phone2 eyeprotect.csv'

phone3_standard = 'phone3 standard.csv'
phone3_eyeprotect = 'phone3 eyeprotect.csv'

# %% [markdown]
# ### add the spectrum in comuter monitor

# %%
computer1 = 'computer1.csv'
computer2 = 'computer2.csv'
computer3 = 'computer3.csv'
computer4 = 'computer4.csv'
computer5 = 'computer5.csv'
computer6 = 'computer6.csv'

# %% [markdown]
# ## spectral pretreatment
# ### remove dark current

# %%
dark_file = 'dark.csv'
dark = read_mean_dark(screen_path,dark_file)

# %%
WL_interp = np.linspace(380,780,401)     #插值点波长

# %%
font_title = {'family' : 'Arial',
              'weight' : 'bold',
              'size'   : 10,
             }
font_keys = {'family' : 'Arial',
             'weight' : 'regular',
             'size'   : 8,
            }
fig_width = 7.5
fig_heigh = 5
dpi1 = 100
dpi2 = 200

# %% [markdown]
# **total_pretreatment contain remove dark current, mean, intercept, and normalize.**

# %%
phone1_standard_spec = total_pretreatment(screen_path,phone1_standard,WL_interp,dark)
phone1_eyeprotect_spec = total_pretreatment(screen_path,phone1_eyeprotect,WL_interp,dark)

phone2_standard_spec = total_pretreatment(screen_path,phone2_standard,WL_interp,dark)
phone2_eyeprotect_spec = total_pretreatment(screen_path,phone2_eyeprotect,WL_interp,dark)

phone3_standard_spec = total_pretreatment(screen_path,phone3_standard,WL_interp,dark)
phone3_eyeprotect_spec = total_pretreatment(screen_path,phone3_eyeprotect,WL_interp,dark)

computer1_spec = total_pretreatment(screen_path,computer1,WL_interp,dark)
computer2_spec = total_pretreatment(screen_path,computer2,WL_interp,dark)
computer3_spec = total_pretreatment(screen_path,computer3,WL_interp,dark)
computer4_spec = total_pretreatment(screen_path,computer4,WL_interp,dark)
computer5_spec = total_pretreatment(screen_path,computer5,WL_interp,dark)
computer6_spec = total_pretreatment(screen_path,computer6,WL_interp,dark)

# %%
plt.figure(figsize=(7.5,7.5),dpi=dpi2)

plt.subplot(3,3,1)
plt.xlabel('lambda/nm',font_title,labelpad=0)
plt.ylabel('intensity',font_title,labelpad=0)
plt.plot(WL_interp,phone1_standard_spec,'-',linewidth = 1.5,markersize = 8,label='phone1 standard')
plt.plot(WL_interp,phone1_eyeprotect_spec,'-',linewidth = 1.5,markersize = 8,label='phone1 eye protect')
plt.tick_params(labelsize=8,pad=0.01)
plt.legend(loc='upper right',prop = {'size':8})
plt.title('A',font_title,x=0,y=1)
plt.ylim(-0.1,1.3)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',400))

plt.subplot(3,3,2)
plt.xlabel('lambda/nm',font_title,labelpad=0)
plt.ylabel('intensity',font_title,labelpad=0)
plt.plot(WL_interp,phone2_standard_spec,'-',linewidth = 1.5,markersize = 8,label='phone2 standard')
plt.plot(WL_interp,phone2_eyeprotect_spec,'-',linewidth = 1.5,markersize = 8,label='phone2 eye protect')
plt.tick_params(labelsize=8,pad=0.01)
plt.legend(loc='upper right',prop = {'size':8})
plt.title('B',font_title,x=0,y=1)
plt.ylim(-0.1,1.3)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',400))

plt.subplot(3,3,3)
plt.xlabel('lambda/nm',font_title,labelpad=0)
plt.ylabel('intensity',font_title,labelpad=0)
plt.plot(WL_interp,phone3_standard_spec,'-',linewidth = 1.5,markersize = 8,label='phone3 standard')
plt.plot(WL_interp,phone3_eyeprotect_spec,'-',linewidth = 1.5,markersize = 8,label='phone3 eye protect')
plt.tick_params(labelsize=8,pad=0.01)
plt.legend(loc='upper right',prop = {'size':8})
plt.title('C',font_title,x=0,y=1)
plt.ylim(-0.1,1.3)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',400))

plt.subplot(3,3,4)
plt.xlabel('lambda/nm',font_title,labelpad=0)
plt.ylabel('intensity',font_title,labelpad=0)
plt.plot(WL_interp,computer1_spec,'-',linewidth = 1.5,markersize = 8,label='computer1')
plt.tick_params(labelsize=8,pad=0.01)
plt.legend(loc='upper right',prop = {'size':8})
plt.title('D',font_title,x=0,y=1)
plt.ylim(-0.1,1.2)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',400))

plt.subplot(3,3,5)
plt.xlabel('lambda/nm',font_title,labelpad=0)
plt.ylabel('intensity',font_title,labelpad=0)
plt.plot(WL_interp,computer2_spec,'-',linewidth = 1.5,markersize = 8,label='computer2')
plt.tick_params(labelsize=8,pad=0.01)
plt.legend(loc='upper right',prop = {'size':8})
plt.title('E',font_title,x=0,y=1)
plt.ylim(-0.1,1.2)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',400))

plt.subplot(3,3,6)
plt.xlabel('lambda/nm',font_title,labelpad=0)
plt.ylabel('intensity',font_title,labelpad=0)
plt.plot(WL_interp,computer3_spec,'-',linewidth = 1.5,markersize = 8,label='computer3')
plt.tick_params(labelsize=8,pad=0.01)
plt.legend(loc='upper right',prop = {'size':8})
plt.title('F',font_title,x=0,y=1)
plt.ylim(-0.1,1.2)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',400))

plt.subplot(3,3,7)
plt.xlabel('lambda/nm',font_title,labelpad=0)
plt.ylabel('intensity',font_title,labelpad=0)
plt.plot(WL_interp,computer4_spec,'-',linewidth = 1.5,markersize = 8,label='computer4')
plt.tick_params(labelsize=8,pad=0.01)
plt.legend(loc='upper right',prop = {'size':8})
plt.title('G',font_title,x=0,y=1)
plt.ylim(-0.1,1.2)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',400))

plt.subplot(3,3,8)
plt.xlabel('lambda/nm',font_title,labelpad=0)
plt.ylabel('intensity',font_title,labelpad=0)
plt.plot(WL_interp,computer5_spec,'-',linewidth = 1.5,markersize = 8,label='computer5')
plt.tick_params(labelsize=8,pad=0.01)
plt.legend(loc='upper right',prop = {'size':8})
plt.title('H',font_title,x=0,y=1)
plt.ylim(-0.1,1.2)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',400))

plt.subplot(3,3,9)
plt.xlabel('lambda/nm',font_title,labelpad=0)
plt.ylabel('intensity',font_title,labelpad=0)
plt.plot(WL_interp,computer6_spec,'-',linewidth = 1.5,markersize = 8,label='computer6')
plt.tick_params(labelsize=8,pad=0.01)
plt.legend(loc='upper right',prop = {'size':8})
plt.title('I',font_title,x=0,y=1)
plt.ylim(-0.1,1.2)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',400))

plt.tight_layout()
plt.subplots_adjust(wspace=0.1,hspace=0.2)
plt.savefig(picture_path+'Figure1.tiff',dpi=dpi2,bbox_inches='tight')
plt.show()

# %% [markdown]
# # chroma analysis
# ### input the Visual tristimulus values

# %%
from chroma import  chroma_cordinate1931,CCT,trans_1931_1976,XYZ,blackbody1931   #主要包含各类预处理命令
# Out:
# importing Jupyter notebook from chroma.ipynb

# %%
X_lambda,Y_lambda,Z_lambda = XYZ(WL_interp)

# %%
plt.figure(figsize=(10,5))
plt.xlabel('lambda/nm',font_title,horizontalalignment='right',x=0.9)
plt.plot(WL_interp,X_lambda,'-',color=(1,0,0))
plt.plot(WL_interp,Y_lambda,'-',color=(0,1,0))
plt.plot(WL_interp,Z_lambda,'-',color=(0,0,1))
plt.legend(['X','Y','Z'])
plt.show()

# %% [markdown]
# ### input the blckbody data in CIE1931 color map and translate to CIE1976

# %%
x_black,y_black = blackbody1931()
(u1976_black,v1976_black) = trans_1931_1976(x_black,y_black)

# %%
(phone1_standard_x,phone1_standard_y) = chroma_cordinate1931(phone1_standard_spec,X_lambda,Y_lambda,Z_lambda)
(phone1_eyeprotect_x,phone1_eyeprotect_y) = chroma_cordinate1931(phone1_eyeprotect_spec,X_lambda,Y_lambda,Z_lambda)
print('phone1 standard = （%.4f,%.4f）'%(phone1_standard_x,phone1_standard_y)+
      '\n'+'phone1 eyeprotect = （%.4f,%.4f）'%(phone1_eyeprotect_x,phone1_eyeprotect_y))

(phone2_standard_x,phone2_standard_y) = chroma_cordinate1931(phone2_standard_spec,X_lambda,Y_lambda,Z_lambda)
(phone2_eyeprotect_x,phone2_eyeprotect_y) = chroma_cordinate1931(phone2_eyeprotect_spec,X_lambda,Y_lambda,Z_lambda)
print('\n'+'phone2 standard = （%.4f,%.4f）'%(phone2_standard_x,phone2_standard_y)+
      '\n'+'phone2 eyeprotect = （%.4f,%.4f）'%(phone2_eyeprotect_x,phone2_eyeprotect_y))

(phone3_standard_x,phone3_standard_y) = chroma_cordinate1931(phone3_standard_spec,X_lambda,Y_lambda,Z_lambda)
(phone3_eyeprotect_x,phone3_eyeprotect_y) = chroma_cordinate1931(phone3_eyeprotect_spec,X_lambda,Y_lambda,Z_lambda)
print('\n'+'phone3 standard = （%.4f,%.4f）'%(phone3_standard_x,phone3_standard_y)+
      '\n'+'phone3 eyeprotect = （%.4f,%.4f）'%(phone3_eyeprotect_x,phone3_eyeprotect_y))
# Out:
# phone1 standard = （0.3679,0.3817）
# phone1 eyeprotect = （0.4507,0.4331）
#
# phone2 standard = （0.3361,0.3622）
# phone2 eyeprotect = （0.4152,0.4150）
#
# phone3 standard = （0.3208,0.3443）
# phone3 eyeprotect = （0.4068,0.4161）

# %%
plt.figure(figsize=(2.5,2.5))
colour.plotting.plot_chromaticity_diagram_CIE1931(standalone=False)
plt.plot(phone1_standard_x,phone1_standard_y,'*',markersize=8,color=(0,1,0),label='phone1 standard')
plt.plot(phone1_eyeprotect_x,phone1_eyeprotect_y,'o',markersize=8,color=(0,1,0),label='phone1 eyeprotect')
plt.plot(phone2_standard_x,phone2_standard_y,'*',markersize=8,color=(0,0,1),label='phone2 standard')
plt.plot(phone2_eyeprotect_x,phone2_eyeprotect_y,'o',markersize=8,color=(0,0,1),label='phone2 eyeprotect')
plt.plot(phone3_standard_x,phone3_standard_y,'*',markersize=8,color=(1,0,0),label='phone3 standard')
plt.plot(phone3_eyeprotect_x,phone3_eyeprotect_y,'o',markersize=8,color=(1,0,0),label='phone3 eyeprotect')
plt.plot(x_black,y_black,'-',color=(0,0,0))
plt.tick_params(labelsize=8,pad=0.01)
plt.legend()
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))
plt.axis([-0.1,1,-0.1,1])
plt.title('A',font_title,x=0,y=1)
plt.savefig(picture_path+'Figure2A.tiff',dpi=dpi2,bbox_inches='tight')
plt.show()

# %%
(computer1_x,computer1_y) = chroma_cordinate1931(computer1_spec,X_lambda,Y_lambda,Z_lambda)
(computer2_x,computer2_y) = chroma_cordinate1931(computer2_spec,X_lambda,Y_lambda,Z_lambda)
(computer3_x,computer3_y) = chroma_cordinate1931(computer3_spec,X_lambda,Y_lambda,Z_lambda)
(computer4_x,computer4_y) = chroma_cordinate1931(computer4_spec,X_lambda,Y_lambda,Z_lambda)
(computer5_x,computer5_y) = chroma_cordinate1931(computer5_spec,X_lambda,Y_lambda,Z_lambda)
(computer6_x,computer6_y) = chroma_cordinate1931(computer6_spec,X_lambda,Y_lambda,Z_lambda)
print("computer1 = （%.4f,%.4f）"%(computer1_x,computer1_y)+
      '\n'+"computer2 = （%.4f,%.4f）"%(computer2_x,computer2_y)+
      '\n'+"computer3 = （%.4f,%.4f）"%(computer3_x,computer3_y)+
      '\n'+"computer4 = （%.4f,%.4f）"%(computer4_x,computer4_y)+
      '\n'+"computer5 = （%.4f,%.4f）"%(computer5_x,computer5_y)+
      '\n'+"computer6 = （%.4f,%.4f）"%(computer6_x,computer6_y))
# Out:
# computer1 = （0.3419,0.3683）
# computer2 = （0.3204,0.3551）
# computer3 = （0.3358,0.3770）
# computer4 = （0.3257,0.3520）
# computer5 = （0.3398,0.3751）
# computer6 = （0.3454,0.3659）

# %%
plt.figure(figsize=(2.5,2.5))
colour.plotting.plot_chromaticity_diagram_CIE1931(figsize=(2.5,2.5),standalone=False)
plt.plot(phone1_standard_x,phone1_standard_y,'*',markersize=8,color=(0,1,0),label='phone1 standard')
plt.plot(phone1_eyeprotect_x,phone1_eyeprotect_y,'o',markersize=8,color=(0,1,0),label='phone1 eyeprotect')
plt.plot(phone2_standard_x,phone2_standard_y,'*',markersize=8,color=(0,0,1),label='phone2 standard')
plt.plot(phone2_eyeprotect_x,phone2_eyeprotect_y,'o',markersize=8,color=(0,0,1),label='phone2 eyeprotect')
plt.plot(phone3_standard_x,phone3_standard_y,'*',markersize=8,color=(1,0,0),label='phone3 standard')
plt.plot(phone3_eyeprotect_x,phone3_eyeprotect_y,'o',markersize=8,color=(1,0,0),label='phone3 eyeprotect')
plt.plot(computer1_x,computer1_y,'*',markersize=8,label='computer1')
plt.plot(computer2_x,computer2_y,'o',markersize=8,label='computer2')
plt.plot(computer3_x,computer3_y,'^',markersize=8,label='computer3')
plt.plot(computer4_x,computer4_y,'X',markersize=8,label='computer4')
plt.plot(computer5_x,computer5_y,'s',markersize=8,label='computer5')
plt.plot(computer6_x,computer6_y,'d',markersize=8,label='computer6')
plt.plot(x_black,y_black,'-',color=(0,0,0))
plt.tick_params(labelsize=8,pad=0.01)
plt.legend(loc='upper right',prop = {'size':8})

plt.title('B',font_title,x=0,y=1)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))
plt.axis([-0.1,1,-0.1,1])
plt.savefig(picture_path+'Figure2B.tiff',dpi=dpi2,bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(2.5,2.5))
colour.plotting.plot_chromaticity_diagram_CIE1931(figsize=(2.5,2.5),standalone=False)
plt.plot(phone1_standard_x,phone1_standard_y,'*',markersize=8,color=(0,1,0),label='phone1 standard')
plt.plot(phone1_eyeprotect_x,phone1_eyeprotect_y,'o',markersize=8,color=(0,1,0),label='phone1 eyeprotect')
plt.plot(phone2_standard_x,phone2_standard_y,'*',markersize=8,color=(0,0,1),label='phone2 standard')
plt.plot(phone2_eyeprotect_x,phone2_eyeprotect_y,'o',markersize=8,color=(0,0,1),label='phone2 eyeprotect')
plt.plot(phone3_standard_x,phone3_standard_y,'*',markersize=8,color=(1,0,0),label='phone3 standard')
plt.plot(phone3_eyeprotect_x,phone3_eyeprotect_y,'o',markersize=8,color=(1,0,0),label='phone3 eyeprotect')
plt.plot(computer1_x,computer1_y,'*',markersize=8,label='computer1')
plt.plot(computer2_x,computer2_y,'o',markersize=8,label='computer2')
plt.plot(computer3_x,computer3_y,'^',markersize=8,label='computer3')
plt.plot(computer4_x,computer4_y,'X',markersize=8,label='computer4')
plt.plot(computer5_x,computer5_y,'s',markersize=8,label='computer5')
plt.plot(computer6_x,computer6_y,'d',markersize=8,label='computer6')
plt.plot(x_black,y_black,'-',color=(0,0,0))
plt.tick_params(labelsize=8,pad=0.01)
plt.title('C',font_title,x=0,y=1)
plt.legend(loc='upper left',prop = {'size':8})


plt.axis([0.3,0.5,0.3,0.5])
plt.savefig(picture_path+'Figure2C.tiff',dpi=dpi2,bbox_inches='tight')

plt.show()

# %%
colour.plotting.plot_chromaticity_diagram_CIE1931(figsize=(3.5,3.5),dpi=dpi2,standalone=False)
plt.plot(phone1_standard_x,phone1_standard_y,'*',markersize=8,color=(0,1,0),label='phone1 standard')
plt.plot(phone1_eyeprotect_x,phone1_eyeprotect_y,'o',markersize=8,color=(0,1,0),label='phone1 eyeprotect')
plt.plot(phone2_standard_x,phone2_standard_y,'*',markersize=8,color=(0,0,1),label='phone2 standard')
plt.plot(phone2_eyeprotect_x,phone2_eyeprotect_y,'o',markersize=8,color=(0,0,1),label='phone2 eyeprotect')
plt.plot(phone3_standard_x,phone3_standard_y,'*',markersize=8,color=(1,0,0),label='phone3 standard')
plt.plot(phone3_eyeprotect_x,phone3_eyeprotect_y,'o',markersize=8,color=(1,0,0),label='phone3 eyeprotect')
plt.plot(computer1_x,computer1_y,'*',markersize=8,label='computer1')
plt.plot(computer2_x,computer2_y,'o',markersize=8,label='computer2')
plt.plot(computer3_x,computer3_y,'^',markersize=8,label='computer3')
plt.plot(computer4_x,computer4_y,'X',markersize=8,label='computer4')
plt.plot(computer5_x,computer5_y,'s',markersize=8,label='computer5')
plt.plot(computer6_x,computer6_y,'d',markersize=8,label='computer6')
plt.plot(x_black,y_black,'-',color=(0,0,0))
plt.legend(loc='upper left',prop = {'size':8})

plt.axis([0.3,0.5,0.3,0.5])
plt.savefig(picture_path+'Figure2.tiff',dpi=dpi2,bbox_inches='tight')
plt.show()

# %% [markdown]
# ## correlated color temperature (CCT)

# %%
phone1_standard_CCT = CCT(phone1_standard_x,phone1_standard_y)
phone1_eyeprotect_CCT = CCT(phone1_eyeprotect_x,phone1_eyeprotect_y)

phone2_standard_CCT = CCT(phone2_standard_x,phone2_standard_y)
phone2_eyeprotect_CCT = CCT(phone2_eyeprotect_x,phone2_eyeprotect_y)

phone3_standard_CCT = CCT(phone3_standard_x,phone3_standard_y)
phone3_eyeprotect_CCT = CCT(phone3_eyeprotect_x,phone3_eyeprotect_y)

# %%
print('\n'+'phone1 standard = %dK'%phone1_standard_CCT+'\n'+'phone1 eyeprotect = %dK'%phone1_eyeprotect_CCT)
print('\n'+'phone2 standard = %dK'%phone2_standard_CCT+'\n'+'phone2 eyeprotect = %dK'%phone2_eyeprotect_CCT)
print('\n'+'phone3 standard = %dK'%phone3_standard_CCT+'\n'+'phone3 eyeprotect = %dK'%phone3_eyeprotect_CCT)
# Out:
# phone1 standard = 4386K
# phone1 eyeprotect = 3008K
#
# phone2 standard = 5371K
# phone2 eyeprotect = 3482K
#
# phone3 standard = 6030K
# phone3 eyeprotect = 3658K

# %%
computer1_CCT = CCT(computer1_x,computer1_y)
computer2_CCT = CCT(computer2_x,computer2_y)
computer3_CCT = CCT(computer3_x,computer3_y)
computer4_CCT = CCT(computer4_x,computer4_y)
computer5_CCT = CCT(computer5_x,computer5_y)
computer6_CCT = CCT(computer6_x,computer6_y)
print('computer1 CCT = %dK'%computer1_CCT)
print('computer2 CCT = %dK'%computer2_CCT)
print('computer3 CCT = %dK'%computer3_CCT)
print('computer4 CCT = %dK'%computer4_CCT)
print('computer5 CCT = %dK'%computer5_CCT)
print('computer6 CCT = %dK'%computer6_CCT)
# Out:
# computer1 CCT = 5169K
# computer2 CCT = 6023K
# computer3 CCT = 5403K
# computer4 CCT = 5795K
# computer5 CCT = 5257K
# computer6 CCT = 5036K

# %% [markdown]
#  ### CIE1976

# %%
(phone1_standard_x1976,phone1_standard_y1976) = trans_1931_1976(phone1_standard_x,phone1_standard_y)
(phone1_eyeprotect_x1976,phone1_eyeprotect_y1976) = trans_1931_1976(phone1_eyeprotect_x,phone1_eyeprotect_y)
print("CIE1976"+'\n'+
      'phone1 standard = （%.4f,%.4f）'%(phone1_standard_x1976,phone1_standard_y1976)+
      '\n'+'phone1 eyeprotect = （%.4f,%.4f）'%(phone1_eyeprotect_x1976,phone1_eyeprotect_y1976))

#nova
(phone2_standard_x1976,phone2_standard_y1976) = trans_1931_1976(phone2_standard_x,phone2_standard_y)
(phone2_eyeprotect_x1976,phone2_eyeprotect_y1976) = trans_1931_1976(phone2_eyeprotect_x,phone2_eyeprotect_y)
print('phone2 standard = （%.4f,%.4f）'%(phone2_standard_x1976,phone2_standard_y1976)+
      '\n'+'phone2 eyeprotect = （%.4f,%.4f）'%(phone2_eyeprotect_x1976,phone2_eyeprotect_y1976))

#oppo
(phone3_standard_x1976,phone3_standard_y1976) = trans_1931_1976(phone3_standard_x,phone3_standard_y)
(phone3_eyeprotect_x1976,phone3_eyeprotect_y1976) = trans_1931_1976(phone3_eyeprotect_x,phone3_eyeprotect_y)
print('phone3 standard = （%.4f,%.4f）'%(phone3_standard_x1976,phone3_standard_y1976)+
      '\n'+'phone3 eyeprotect = （%.4f,%.4f）'%(phone3_eyeprotect_x1976,phone3_eyeprotect_y1976))
# Out:
# CIE1976
# phone1 standard = （0.2150,0.5019）
# phone1 eyeprotect = （0.2471,0.5343）
# phone2 standard = （0.2015,0.4884）
# phone2 eyeprotect = （0.2323,0.5224）
# phone3 standard = （0.1977,0.4775）
# phone3 eyeprotect = （0.2267,0.5216）

# %%
plt.figure(figsize=(10,10))
colour.plotting.plot_chromaticity_diagram_CIE1976UCS(standalone=False)
plt.plot(phone1_standard_x1976,phone1_standard_y1976,'*',markersize=8,color=(0,1,0),label='phone1 standard')
plt.plot(phone1_eyeprotect_x1976,phone1_eyeprotect_y1976,'o',markersize=8,color=(0,1,0),label='phone1 eyeprotect')
plt.plot(phone2_standard_x1976,phone2_standard_y1976,'*',markersize=8,color=(0,0,1),label='phone2 standard')
plt.plot(phone2_eyeprotect_x1976,phone2_eyeprotect_y1976,'o',markersize=8,color=(0,0,1),label='phone2 eyeprotect')
plt.plot(phone3_standard_x1976,phone3_standard_y1976,'*',markersize=8,color=(1,0,0),label='phone3 standard')
plt.plot(phone3_eyeprotect_x1976,phone3_eyeprotect_y1976,'o',markersize=8,color=(1,0,0),label='phone3 eyeprotect')
plt.plot(u1976_black,v1976_black,'-',color=(0,0,0))
plt.legend()
plt.axis([-0.1,0.7,-0.1,0.7])
# Out:
# [-0.1, 0.7, -0.1, 0.7]

# %%
plt.figure(figsize=(10,10))
colour.plotting.plot_chromaticity_diagram_CIE1976UCS(standalone=False)
plt.plot(phone1_standard_x1976,phone1_standard_y1976,'*',markersize=8,color=(0,1,0),label='phone1 standard')
plt.plot(phone1_eyeprotect_x1976,phone1_eyeprotect_y1976,'o',markersize=8,color=(0,1,0),label='phone1 eyeprotect')
plt.plot(phone2_standard_x1976,phone2_standard_y1976,'*',markersize=8,color=(0,0,1),label='phone2 standard')
plt.plot(phone2_eyeprotect_x1976,phone2_eyeprotect_y1976,'o',markersize=8,color=(0,0,1),label='phone2 eyeprotect')
plt.plot(phone3_standard_x1976,phone3_standard_y1976,'*',markersize=8,color=(1,0,0),label='phone3 standard')
plt.plot(phone3_eyeprotect_x1976,phone3_eyeprotect_y1976,'o',markersize=8,color=(1,0,0),label='phone3 eyeprotect')
plt.plot(u1976_black,v1976_black,'-',color=(0,0,0))
plt.axis([0.15,0.30,0.4,0.6])
plt.legend()
plt.show()

# %% [markdown]
# # blue light hazard factor and circadian factor

# %%
from chroma import KB,KC,V,C,B,RB

# %%
plt.figure(figsize=(3.5,2.5),dpi=dpi2)
plt.xlabel('lambda/nm',font_title,labelpad=0)
plt.ylabel('intensity',font_title,labelpad=0)
plt.plot(WL_interp,V(WL_interp),label='photonic vision')
plt.plot(WL_interp,B(WL_interp),label='blue light hazard')
plt.plot(WL_interp,C(WL_interp),label='circadian effect')
plt.tick_params(labelsize=8,pad=0.01)
plt.ylim(0,1.1)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',380))
plt.legend(loc='upper right',prop = {'size':8})
plt.savefig(picture_path+'Figure3.tiff',dpi=dpi2,bbox_inches='tight')
plt.show()

# %%
phone1_standard_KB = KB(phone1_standard_spec,WL_interp)
phone1_eyeprotect_KB = KB(phone1_eyeprotect_spec,WL_interp)
phone2_standard_KB = KB(phone2_standard_spec,WL_interp)
phone2_eyeprotect_KB = KB(phone2_eyeprotect_spec,WL_interp)
phone3_standard_KB = KB(phone3_standard_spec,WL_interp)
phone3_eyeprotect_KB = KB(phone3_eyeprotect_spec,WL_interp)

print('phone1 standard blue light hazard factor%.10f'%(phone1_standard_KB))
print('phone1 eyeprotect blue light hazard factor%.10f'%(phone1_eyeprotect_KB))
print('phone2 standard blue light hazard factor%.10f'%(phone2_standard_KB))
print('phone2 eyeprotect blue light hazard factor%.10f'%(phone2_eyeprotect_KB))
print('phone3 standard blue light hazard factor%.10f'%(phone3_standard_KB))
print('phone3 eyeprotect blue light hazard factor%.10f'%(phone3_eyeprotect_KB))
# Out:
# phone1 standard blue light hazard factor0.0005265238
# phone1 eyeprotect blue light hazard factor0.0002161791
# phone2 standard blue light hazard factor0.0006182063
# phone2 eyeprotect blue light hazard factor0.0003028622
# phone3 standard blue light hazard factor0.0007525310
# phone3 eyeprotect blue light hazard factor0.0003276003

# %%
computer1_KB = KB(computer1_spec,WL_interp)
computer2_KB = KB(computer2_spec,WL_interp)
computer3_KB = KB(computer3_spec,WL_interp)
computer4_KB = KB(computer4_spec,WL_interp)
computer5_KB = KB(computer5_spec,WL_interp)
computer6_KB = KB(computer6_spec,WL_interp)

print('computer1 blue light hazard factor%.10f'%(computer1_KB))
print('computer2 blue light hazard factor%.10f'%(computer2_KB))
print('computer3 blue light hazard factor%.10f'%(computer3_KB))
print('computer4 blue light hazard factor%.10f'%(computer4_KB))
print('computer5 blue light hazard factor%.10f'%(computer5_KB))
print('computer6 blue light hazard factor%.10f'%(computer6_KB))
# Out:
# computer1 blue light hazard factor0.0006328729
# computer2 blue light hazard factor0.0007198825
# computer3 blue light hazard factor0.0006277617
# computer4 blue light hazard factor0.0007053845
# computer5 blue light hazard factor0.0005805796
# computer6 blue light hazard factor0.0006239236

# %%
phone1_standard_KC = KC(phone1_standard_spec,WL_interp)
phone1_eyeprotect_KC = KC(phone1_eyeprotect_spec,WL_interp)
phone2_standard_KC = KC(phone2_standard_spec,WL_interp)
phone2_eyeprotect_KC = KC(phone2_eyeprotect_spec,WL_interp)
phone3_standard_KC = KC(phone3_standard_spec,WL_interp)
phone3_eyeprotect_KC = KC(phone3_eyeprotect_spec,WL_interp)

print('phone1 standard circadian factor%f'%(phone1_standard_KC))
print('phone1 eyeprotect circadian factor%f'%(phone1_eyeprotect_KC))
print('phone2 standard circadian factor%f'%(phone2_standard_KC))
print('phone2 eyeprotect circadian factor%f'%(phone2_eyeprotect_KC))
print('phone3 standard circadian factor%f'%(phone3_standard_KC))
print('phone3 eyeprotect circadian factor%f'%(phone3_eyeprotect_KC))
# Out:
# phone1 standard circadian factor1.903910
# phone1 eyeprotect circadian factor0.781704
# phone2 standard circadian factor2.235434
# phone2 eyeprotect circadian factor1.095150
# phone3 standard circadian factor2.721152
# phone3 eyeprotect circadian factor1.184603

# %%
computer1_KC = KC(computer1_spec,WL_interp)
computer2_KC = KC(computer2_spec,WL_interp)
computer3_KC = KC(computer3_spec,WL_interp)
computer4_KC = KC(computer4_spec,WL_interp)
computer5_KC = KC(computer5_spec,WL_interp)
computer6_KC = KC(computer6_spec,WL_interp)

print('computer1 circadian factor%f'%(computer1_KC))
print('computer2 circadian factor%f'%(computer2_KC))
print('computer3 circadian factor%f'%(computer3_KC))
print('computer4 circadian factor%f'%(computer4_KC))
print('computer5 circadian factor%f'%(computer5_KC))
print('computer6 circadian factor%f'%(computer6_KC))
# Out:
# computer1 circadian factor2.288468
# computer2 circadian factor2.603095
# computer3 circadian factor2.269986
# computer4 circadian factor2.550670
# computer5 circadian factor2.099376
# computer6 circadian factor2.256108

# %%
phone1_standard_RB = RB(phone1_standard_spec)
phone1_eyeprotect_RB = RB(phone1_eyeprotect_spec)
phone2_standard_RB = RB(phone2_standard_spec)
phone2_eyeprotect_RB = RB(phone2_eyeprotect_spec)
phone3_standard_RB = RB(phone3_standard_spec)
phone3_eyeprotect_RB = RB(phone3_eyeprotect_spec)

print('phone1 standard blue light ratio%f'%(phone1_standard_RB))
print('phone1 eyeprotect blue light ratio%f'%(phone1_eyeprotect_RB))
print('phone2 standard blue light ratio%f'%(phone2_standard_RB))
print('phone2 eyeprotect blue light ratio%f'%(phone2_eyeprotect_RB))
print('phone3 standard blue light ratio%f'%(phone3_standard_RB))
print('phone3 eyeprotect blue light ratio%f'%(phone3_eyeprotect_RB))
# Out:
# phone1 standard blue light ratio0.191971
# phone1 eyeprotect blue light ratio0.081220
# phone2 standard blue light ratio0.241865
# phone2 eyeprotect blue light ratio0.125182
# phone3 standard blue light ratio0.261399
# phone3 eyeprotect blue light ratio0.122260

# %%
computer1_RB = RB(computer1_spec)
computer2_RB = RB(computer2_spec)
computer3_RB = RB(computer3_spec)
computer4_RB = RB(computer4_spec)
computer5_RB = RB(computer5_spec)
computer6_RB = RB(computer6_spec)

print('computer1 blue light ratio%f'%(computer1_RB))
print('computer2 blue light ratio%f'%(computer2_RB))
print('computer3 blue light ratio%f'%(computer3_RB))
print('computer4 blue light ratio%f'%(computer4_RB))
print('computer5 blue light ratio%f'%(computer5_RB))
print('computer6 blue light ratio%f'%(computer6_RB))
# Out:
# computer1 blue light ratio0.233132
# computer2 blue light ratio0.285809
# computer3 blue light ratio0.334437
# computer4 blue light ratio0.268536
# computer5 blue light ratio0.248473
# computer6 blue light ratio0.231902

# %%
from scipy import stats

# %%
phone1_standard_Z = 1-phone1_standard_x-phone1_standard_y
phone2_standard_Z = 1-phone2_standard_x-phone2_standard_y
phone3_standard_Z = 1-phone3_standard_x-phone3_standard_y
phone1_eyeprotect_Z = 1-phone1_eyeprotect_x-phone1_eyeprotect_y
phone2_eyeprotect_Z = 1-phone2_eyeprotect_x-phone2_eyeprotect_y
phone3_eyeprotect_Z = 1-phone3_eyeprotect_x-phone3_eyeprotect_y 

computer1_Z = 1-computer1_x-computer1_y
computer2_Z = 1-computer2_x-computer2_y
computer3_Z = 1-computer3_x-computer3_y
computer4_Z = 1-computer4_x-computer4_y
computer5_Z = 1-computer5_x-computer5_y
computer6_Z = 1-computer6_x-computer6_y 

print('phone1 standard Z:%f'%(phone1_standard_Z))
print('phone1 eyeprotect Z:%f'%(phone1_eyeprotect_Z))
print('phone2 standard Z:%f'%(phone2_standard_Z))
print('phone2 eyeprotect Z:%f'%(phone2_eyeprotect_Z))
print('phone3 standard Z:%f'%(phone3_standard_Z))
print('phone3 eyeprotect Z:%f'%(phone3_eyeprotect_Z))

print('computer1 Z:%f'%(computer1_Z))
print('computer2 Z:%f'%(computer2_Z))
print('computer3 Z:%f'%(computer3_Z))
print('computer4 Z:%f'%(computer4_Z))
print('computer5 Z:%f'%(computer5_Z))
print('computer6 Z:%f'%(computer6_Z))
# Out:
# phone1 standard Z:0.250424
# phone1 eyeprotect Z:0.116236
# phone2 standard Z:0.301702
# phone2 eyeprotect Z:0.169756
# phone3 standard Z:0.334912
# phone3 eyeprotect Z:0.177084
# computer1 Z:0.289805
# computer2 Z:0.324562
# computer3 Z:0.287171
# computer4 Z:0.322323
# computer5 Z:0.285053
# computer6 Z:0.288667

# %%
Z = [phone1_standard_Z,phone2_standard_Z,phone3_standard_Z,
     phone1_eyeprotect_Z,phone2_eyeprotect_Z,phone3_eyeprotect_Z,
     computer1_Z,computer2_Z,computer3_Z,computer4_Z,computer5_Z,computer6_Z]
CCT = [phone1_standard_CCT,phone2_standard_CCT,phone3_standard_CCT,
       phone1_eyeprotect_CCT,phone2_eyeprotect_CCT,phone3_eyeprotect_CCT,
       computer1_CCT,computer2_CCT,computer3_CCT,computer4_CCT,computer5_CCT,computer6_CCT]
CP = [0.10522,0.12840,0.12483,0.05548,0.07477,0.08056,
      0.07113,0.06038,0.06599,0.12638,0.10760,0.11601]   #3D gamut
blue_light_ratio = [phone1_standard_RB,phone2_standard_RB,phone3_standard_RB,
                    phone1_eyeprotect_RB,phone2_eyeprotect_RB,phone3_eyeprotect_RB,
                    computer1_RB,computer2_RB,computer3_RB,computer4_RB,computer5_RB,computer6_RB]


list1 = (0,1,2,3,4,5,9,10,11)
print(type(list1))
print([CP[i] for i in list1])
# Out:
# <class 'tuple'>
# [0.10522, 0.1284, 0.12483, 0.05548, 0.07477, 0.08056, 0.12638, 0.1076, 0.11601]

# %%
blue_light_hazard_factor = [phone1_standard_KB*10**4,phone2_standard_KB*10**4,phone3_standard_KB*10**4,
                            phone1_eyeprotect_KB*10**4,phone2_eyeprotect_KB*10**4,phone3_eyeprotect_KB*10**4,
                            computer1_KB*10**4,computer2_KB*10**4,computer3_KB*10**4,
                            computer4_KB*10**4,computer5_KB*10**4,computer6_KB*10**4]

circadian_factor = [phone1_standard_KC,phone2_standard_KC,phone3_standard_KC,
                    phone1_eyeprotect_KC,phone2_eyeprotect_KC,phone3_eyeprotect_KC,
                    computer1_KC,computer2_KC,computer3_KC,computer4_KC,computer5_KC,computer6_KC]

# %%
plt.figure(figsize=(7.5,6),dpi=dpi2)

plt.subplot(2,2,1)
plt.xlabel('chroma coordinate Z value',font_title,labelpad=0)
plt.ylabel('blue light hazard factor(x10$^{-4}$ W/ml)',font_title,labelpad=0)
plt.plot(Z,blue_light_hazard_factor,'*',linewidth = 1.5,markersize = 8)
plt.tick_params(labelsize=8,pad=0.01)
min_Z = min(Z)
max_Z = max(Z)
Z_x = np.arange(min_Z,max_Z,(max_Z-min_Z)/100)
slope,intercept,R,P,std_err = stats.linregress(Z,blue_light_hazard_factor)
Z_y = np.array([intercept+slope*x for x in Z_x])
plt.text(min_Z*1.2,(intercept+slope*max_Z)*0.8,
         'y=%s*x+%s'%(np.around(slope,5),np.around(intercept,5))+'\n'+'R$^2$=%s'%(np.around(R,5)),
         fontsize=8)
plt.plot(Z_x,Z_y,'-',linewidth = 1.5)

plt.tick_params(font_keys)
plt.title('A',font_title,x=0,y=1)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.subplot(2,2,2)
plt.xlabel('correlated color temperature(K)',font_title,labelpad=0)
plt.ylabel('blue light hazard factor(x10$^{-4}$ W/ml)',font_title,labelpad=0)
plt.plot(CCT,blue_light_hazard_factor,'*',linewidth = 1.5,markersize = 8)
plt.tick_params(labelsize=8,pad=0.01)
min_CCT = min(CCT)
max_CCT = max(CCT)
CCT_x = np.arange(min_CCT,max_CCT,(max_CCT-min_CCT)/100)
slope,intercept,R,P,std_err = stats.linregress(CCT,blue_light_hazard_factor)
CCT_y = np.array([intercept+slope*x for x in CCT_x])
plt.text(min_CCT*1.2,(intercept+slope*max_CCT)*0.8,
         'y=%s*x+%s'%(np.around(slope,5),np.around(intercept,5))+'\n'+'R$^2$=%s'%(np.around(R,5)),
         fontsize=8)
plt.plot(CCT_x,CCT_y,'-',linewidth = 1.5)

plt.tick_params(font_keys)
plt.title('B',font_title,x=0,y=1)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.subplot(2,2,3)
plt.xlabel('3D gamut(%)',font_title,labelpad=0)
plt.ylabel('blue light hazard factor(x10$^{-4}$ W/ml)',font_title,labelpad=0)
plt.plot(CP,blue_light_hazard_factor,'*',linewidth = 1.5,markersize = 8)
plt.plot([CP[i] for i in list1],[blue_light_hazard_factor[i] for i in list1],'*',linewidth = 1.5,markersize = 8)
plt.tick_params(labelsize=8,pad=0.01)
min_CP = min(CP)
max_CP = max(CP)
CP_x = np.arange(min_CP,max_CP,(max_CP-min_CP)/100)
slope,intercept,R,P,std_err = stats.linregress(CP,blue_light_hazard_factor)
slope1,intercept1,R1,P1,std_err1 = stats.linregress([CP[i] for i in list1],[blue_light_hazard_factor[i] for i in list1])
CP_y = np.array([intercept+slope*x for x in CP_x])
CP_y1 = np.array([intercept1+slope1*x for x in CP_x])
plt.text(min_CP*1.2,(intercept+slope*max_CP)*0.8,
         'y=%s*x+%s'%(np.around(slope,5),np.around(intercept,5))+'\n'+'R$^2$=%s'%(np.around(R,5)),
         fontsize=8)
plt.text(min_CP*1.2,(intercept1+slope1*max_CP)*0.5,
         'y=%s*x+%s'%(np.around(slope1,5),np.around(intercept1,5))+'\n'+'R$^2$=%s'%(np.around(R1,5)),
         fontsize=8)
plt.plot(CP_x,CP_y,'-',linewidth = 1.5)
plt.plot(CP_x,CP_y1,'-',linewidth = 1.5)

plt.tick_params(font_keys)
plt.title('C',font_title,x=0,y=1)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.subplot(2,2,4)
plt.xlabel('blue light ratio(%)',font_title,labelpad=0)
plt.ylabel('blue light hazard factor(x10$^{-4}$ W/ml)',font_title,labelpad=0)
plt.plot(blue_light_ratio,blue_light_hazard_factor,'*',linewidth = 1.5,markersize = 8)

min_B = min(blue_light_ratio)
max_B = max(blue_light_ratio)
B_x = np.arange(min_B,max_B,(max_B-min_B)/100)
slope,intercept,R,P,std_err = stats.linregress(blue_light_ratio,blue_light_hazard_factor)
B_y = np.array([intercept+slope*x for x in B_x])
plt.text(min_B*1.2,(intercept+slope*max_B)*0.8,
         'y=%s*x+%s'%(np.around(slope,5),np.around(intercept,5))+'\n'+'R$^2$=%s'%(np.around(R,5)),
         fontsize=8)
plt.plot(B_x,B_y,'-',linewidth = 1.5)
plt.tick_params(labelsize=8,pad=0.01)
plt.tick_params(font_keys)
plt.title('D',font_title,x=0,y=1)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.tight_layout()
plt.subplots_adjust(wspace=0.1,hspace=0.2)
# plt.savefig(picture_path+'Figure5.tiff',dpi=dpi2,bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(7.5,6),dpi = dpi2,frameon = False)
plt.subplot(2,2,1)
plt.xlabel('chroma coordinate Z value',font_title,labelpad=0)
plt.ylabel('circadian factor',font_title,labelpad=0)
plt.plot(Z,circadian_factor,'*',linewidth = 1.5,markersize = 8)
plt.tick_params(labelsize=8,pad=0.01)
min_Z = min(Z)
max_Z = max(Z)
Z_x = np.arange(min_Z,max_Z,(max_Z-min_Z)/100)
slope,intercept,R,P,std_err = stats.linregress(Z,circadian_factor)
Z_y = np.array([intercept+slope*x for x in Z_x])
plt.text(min_Z*1.2,(intercept+slope*max_Z)*0.8,
         'y=%s*x+%s'%(np.around(slope,5),np.around(intercept,5))+'\n'+'R$^2$=%s'%(np.around(R,5)),
         fontsize=8)
plt.plot(Z_x,Z_y,'-',linewidth = 1.5)

plt.tick_params(font_keys)
plt.title('A',font_title,x=0,y=1)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.subplot(2,2,2)
plt.xlabel('correlated color temperature(K)',font_title,labelpad=0)
plt.ylabel('circadian factor',font_title,labelpad=0)
plt.plot(CCT,circadian_factor,'*',linewidth = 1.5,markersize = 8)
plt.tick_params(labelsize=8,pad=0.01)
min_CCT = min(CCT)
max_CCT = max(CCT)
CCT_x = np.arange(min_CCT,max_CCT,(max_CCT-min_CCT)/100)
slope,intercept,R,P,std_err = stats.linregress(CCT,circadian_factor)
CCT_y = np.array([intercept+slope*x for x in CCT_x])
plt.text(min_CCT*1.2,(intercept+slope*max_CCT)*0.8,
         'y=%s*x+%s'%(np.around(slope,5),np.around(intercept,5))+'\n'+'R$^2$=%s'%(np.around(R,5)),
         fontsize=8)
plt.plot(CCT_x,CCT_y,'-',linewidth = 1.5)

plt.tick_params(font_keys)
plt.title('B',font_title,x=0,y=1)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.subplot(2,2,3)
plt.xlabel('3D gamut(%)',font_title,labelpad=0)
plt.ylabel('circadian factor',font_title,labelpad=0)
plt.plot(CP,circadian_factor,'*',linewidth = 1.5,markersize = 8)
plt.plot([CP[i] for i in list1],[circadian_factor[i] for i in list1],'*',linewidth = 1.5,markersize = 8)
plt.tick_params(labelsize=8,pad=0.01)
min_CP = min(CP)
max_CP = max(CP)
CP_x = np.arange(min_CP,max_CP,(max_CP-min_CP)/100)
slope,intercept,R,P,std_err = stats.linregress(CP,circadian_factor)
slope1,intercept1,R1,P1,std_err1 = stats.linregress([CP[i] for i in list1],[circadian_factor[i] for i in list1])
CP_y = np.array([intercept+slope*x for x in CP_x])
CP_y1 = np.array([intercept1+slope1*x for x in CP_x])
plt.text(min_CP*1.2,(intercept+slope*max_CP)*0.8,
         'y=%s*x+%s'%(np.around(slope,5),np.around(intercept,5))+'\n'+'R$^2$=%s'%(np.around(R,5)),
         fontsize=8)
plt.text(min_CP*1.2,(intercept1+slope1*max_CP)*0.5,
         'y=%s*x+%s'%(np.around(slope1,5),np.around(intercept1,5))+'\n'+'R$^2$=%s'%(np.around(R1,5)),
         fontsize=8)
plt.plot(CP_x,CP_y,'-',linewidth = 1.5)
plt.plot(CP_x,CP_y1,'-',linewidth = 1.5)

plt.tick_params(font_keys)
plt.title('C',font_title,x=0,y=1)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.subplot(2,2,4)
plt.xlabel('blue light ratio(%)',font_title,labelpad=0)
plt.ylabel('circadian factor',font_title,labelpad=0)
plt.plot(blue_light_ratio,circadian_factor,'*',linewidth = 1.5,markersize = 8)
plt.tick_params(labelsize=8,pad=0.01)
min_B = min(blue_light_ratio)
max_B = max(blue_light_ratio)
B_x = np.arange(min_B,max_B,(max_B-min_B)/100)
slope,intercept,R,P,std_err = stats.linregress(blue_light_ratio,circadian_factor)
B_y = np.array([intercept+slope*x for x in B_x])
plt.text(min_B*1.2,(intercept+slope*max_B)*0.8,
         'y=%s*x+%s'%(np.around(slope,5),np.around(intercept,5))+'\n'+'R$^2$=%s'%(np.around(R,5)),
         fontsize=8)
plt.plot(B_x,B_y,'-',linewidth = 1.5)

plt.tick_params(font_keys)
plt.title('D',font_title,x=0,y=1)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.tight_layout()
plt.subplots_adjust(wspace=0.1,hspace=0.2)
# plt.savefig(picture_path+'Figure6.tiff',dpi=dpi2,bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(7.5,6),dpi = dpi2,frameon = False)
plt.subplot(3,3,1)
plt.xlabel('chroma coordinate Z value',font_title,labelpad=0)
plt.ylabel('3D gamut',font_title,labelpad=0)
plt.plot(Z,CP,'*',linewidth = 1.5,markersize = 8)
plt.plot([Z[i] for i in list1],[CP[i] for i in list1],'*',linewidth = 1.5,markersize = 8)
plt.tick_params(labelsize=8,pad=0.01)
min_Z = min(Z)
max_Z = max(Z)
Z_x = np.arange(min_Z,max_Z,(max_Z-min_Z)/100)
slope,intercept,R,P,std_err = stats.linregress(Z,CP)
slope1,intercept1,R1,P1,std_err1 = stats.linregress([Z[i] for i in list1],[CP[i] for i in list1])
Z_y = np.array([intercept+slope*x for x in Z_x])
Z_y1 = np.array([intercept1+slope1*x for x in Z_x])
if intercept>0:
    plt.text(min_Z*1.2,(intercept+slope*max_Z)*0.5,
             'y=%s*x+%s'%(np.around(slope,5),np.around(intercept,5))+'\n'+'R$^2$=%s'%(np.around(R,5)),fontsize=8)
if intercept<0:
    plt.text(min_Z*1.2,(intercept+slope*max_Z)*0.5,
             'y=%s*x%s'%(np.around(slope,5),np.around(intercept,5))+'\n'+'R$^2$=%s'%(np.around(R,5)),fontsize=8)
if intercept1>0:
    plt.text(min_Z*1.2,(intercept1+slope1*max_Z)*1,
             'y1=%s*x+%s'%(np.around(slope1,5),np.around(intercept1,5))+'\n'+'R$^2$=%s'%(np.around(R1,5)),fontsize=8)
if intercept1<0:
    plt.text(min_Z*1.2,(intercept1+slope1*max_Z)*1,
             'y1=%s*x%s'%(np.around(slope1,5),np.around(intercept1,5))+'\n'+'R$^2$=%s'%(np.around(R1,5)),fontsize=8)
plt.plot(Z_x,Z_y,'-',linewidth = 1.5)
plt.plot(Z_x,Z_y1,'-',linewidth = 1.5)

plt.tick_params(font_keys)
plt.title('A',font_title,x=0,y=1)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.subplot(3,3,2)
plt.xlabel('correlated color temperature(K)',font_title,labelpad=0)
plt.ylabel('3D gamut',font_title,labelpad=0)
plt.plot(CCT,CP,'*',linewidth = 1.5,markersize = 8)
plt.plot([CCT[i] for i in list1],[CP[i] for i in list1],'*',linewidth = 1.5,markersize = 8)
plt.tick_params(labelsize=8,pad=0.01)
min_CCT = min(CCT)
max_CCT = max(CCT)
CCT_x = np.arange(min_CCT,max_CCT,(max_CCT-min_CCT)/100)
slope,intercept,R,P,std_err = stats.linregress(CCT,CP)
slope1,intercept1,R1,P1,std_err1 = stats.linregress([CCT[i] for i in list1],[CP[i] for i in list1])
CCT_y = np.array([intercept+slope*x for x in CCT_x])
CCT_y1 = np.array([intercept1+slope1*x for x in CCT_x])
if intercept>0:
    plt.text(min_CCT*1.2,(intercept+slope*max_CCT)*0.5,
             'y=%s*x+%s'%(np.around(slope,5),np.around(intercept,5))+'\n'+'R$^2$=%s'%(np.around(R,5)),
             fontsize=8)
if intercept1>0:
    plt.text(min_CCT*1.2,(intercept1+slope1*max_CCT)*1,
             'y1=%s*x+%s'%(np.around(slope1,5),np.around(intercept1,5))+'\n'+'R$^2$=%s'%(np.around(R1,5)),
             fontsize=8)
if intercept<0:
    plt.text(min_CCT*1.2,(intercept+slope*max_CCT)*0.5,
             'y=%s*x%s'%(np.around(slope,5),np.around(intercept,5))+'\n'+'R$^2$=%s'%(np.around(R,5)),
             fontsize=8)
if intercept1<0:
    plt.text(min_CCT*1.2,(intercept1+slope1*max_CCT)*1,
             'y1=%s*x%s'%(np.around(slope1,5),np.around(intercept1,5))+'\n'+'R$^2$=%s'%(np.around(R1,5)),
             fontsize=8)
plt.plot(CCT_x,CCT_y,'-',linewidth = 1.5)
plt.plot(CCT_x,CCT_y1,'-',linewidth = 1.5)

plt.tick_params(font_keys)
plt.title('B',font_title,x=0,y=1)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.subplot(3,3,3)
plt.xlabel('blue light ratio(%)',font_title,labelpad=0)
plt.ylabel('3D gamut',font_title,labelpad=0)
plt.plot(blue_light_ratio,CP,'*',linewidth = 1.5,markersize = 8)
plt.plot([blue_light_ratio[i] for i in list1],[CP[i] for i in list1],'*',linewidth = 1.5,markersize = 8)
plt.tick_params(labelsize=8,pad=0.01)
min_blue_light_ratio = min(blue_light_ratio)
max_blue_light_ratio = max(blue_light_ratio)
blue_light_ratio_x = np.arange(min_blue_light_ratio,max_blue_light_ratio,(max_blue_light_ratio-min_blue_light_ratio)/100)
slope,intercept,R,P,std_err = stats.linregress(blue_light_ratio,CP)
slope1,intercept1,R1,P1,std_err1 = stats.linregress([blue_light_ratio[i] for i in list1],[CP[i] for i in list1])
blue_light_ratio_y = np.array([intercept+slope*x for x in blue_light_ratio_x])
blue_light_ratio_y1 = np.array([intercept1+slope1*x for x in blue_light_ratio_x])
if intercept>0:
    plt.text(min_blue_light_ratio*1.2,(intercept+slope*max_blue_light_ratio)*0.5,
             'y=%s*x+%s'%(np.around(slope,5),np.around(intercept,5))+'\n'+'R$^2$=%s'%(np.around(R,5)),
             fontsize=8)
if intercept1>0:
    plt.text(min_blue_light_ratio*1.2,(intercept1+slope1*max_blue_light_ratio)*1,
             'y1=%s*x+%s'%(np.around(slope1,5),np.around(intercept1,5))+'\n'+'R$^2$=%s'%(np.around(R1,5)),
             fontsize=8)
if intercept<0:
    plt.text(min_blue_light_ratio*1.2,(intercept+slope*max_blue_light_ratio)*0.5,
             'y=%s*x%s'%(np.around(slope,5),np.around(intercept,5))+'\n'+'R$^2$=%s'%(np.around(R,5)),
             fontsize=8)
if intercept1<0:
    plt.text(min_blue_light_ratio*1.2,(intercept1+slope1*max_blue_light_ratio)*1,
             'y1=%s*x%s'%(np.around(slope1,5),np.around(intercept1,5))+'\n'+'R$^2$=%s'%(np.around(R1,5)),
             fontsize=8)
plt.plot(blue_light_ratio_x,blue_light_ratio_y,'-',linewidth = 1.5)
plt.plot(blue_light_ratio_x,blue_light_ratio_y1,'-',linewidth = 1.5)

plt.tick_params(font_keys)
plt.title('C',font_title,x=0,y=1)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.subplot(3,3,4)
plt.xlabel('chroma coordinate Z value',font_title,labelpad=0)
plt.ylabel('blue light hazard factor'+'\n'+'(x10$^{-4}$ W/ml)',font_title,labelpad=0)
plt.plot(Z,blue_light_hazard_factor,'*',linewidth = 1.5,markersize = 8)
plt.tick_params(labelsize=8,pad=0.01)
min_Z = min(Z)
max_Z = max(Z)
Z_x = np.arange(min_Z,max_Z,(max_Z-min_Z)/100)
slope,intercept,R,P,std_err = stats.linregress(Z,blue_light_hazard_factor)
Z_y = np.array([intercept+slope*x for x in Z_x])
if intercept>0:
    plt.text(min_Z*1.2,(intercept+slope*max_Z)*0.8,
             'y=%s*x+%s'%(np.around(slope,5),np.around(intercept,5))+'\n'+'R$^2$=%s'%(np.around(R,5)),
             fontsize=8)
if intercept<0:
    plt.text(min_Z*1.2,(intercept+slope*max_Z)*0.8,
             'y=%s*x%s'%(np.around(slope,5),np.around(intercept,5))+'\n'+'R$^2$=%s'%(np.around(R,5)),
             fontsize=8)
plt.plot(Z_x,Z_y,'-',linewidth = 1.5)

plt.tick_params(font_keys)
plt.title('D',font_title,x=0,y=1)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.subplot(3,3,5)
plt.xlabel('correlated color temperature(K)',font_title,labelpad=0)
plt.ylabel('blue light hazard factor'+'\n'+'(x10$^{-4}$ W/ml)',font_title,labelpad=0)
plt.plot(CCT,blue_light_hazard_factor,'*',linewidth = 1.5,markersize = 8)
plt.tick_params(labelsize=8,pad=0.01)
min_CCT = min(CCT)
max_CCT = max(CCT)
CCT_x = np.arange(min_CCT,max_CCT,(max_CCT-min_CCT)/100)
slope,intercept,R,P,std_err = stats.linregress(CCT,blue_light_hazard_factor)
CCT_y = np.array([intercept+slope*x for x in CCT_x])
if intercept>0:
    plt.text(min_CCT*1,(intercept+slope*max_CCT)*0.8,
             'y=%s*x+%s'%(np.around(slope,5),np.around(intercept,5))+'\n'+'R$^2$=%s'%(np.around(R,5)),fontsize=8)
if intercept<0:
    plt.text(min_CCT*1,(intercept+slope*max_CCT)*0.8,
             'y=%s*x%s'%(np.around(slope,5),np.around(intercept,5))+'\n'+'R$^2$=%s'%(np.around(R,5)),fontsize=8)
plt.plot(CCT_x,CCT_y,'-',linewidth = 1.5)

plt.tick_params(font_keys)
plt.title('E',font_title,x=0,y=1)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.subplot(3,3,6)
plt.xlabel('blue light ratio(%)',font_title,labelpad=0)
plt.ylabel('blue light hazard factor'+'\n'+'(x10$^{-4}$ W/ml)',font_title,labelpad=0)
plt.plot(blue_light_ratio,blue_light_hazard_factor,'*',linewidth = 1.5,markersize = 8)

min_B = min(blue_light_ratio)
max_B = max(blue_light_ratio)
B_x = np.arange(min_B,max_B,(max_B-min_B)/100)
slope,intercept,R,P,std_err = stats.linregress(blue_light_ratio,blue_light_hazard_factor)
B_y = np.array([intercept+slope*x for x in B_x])
if intercept>0:
    plt.text(min_B*1.2,(intercept+slope*max_B)*0.8,
             'y=%s*x+%s'%(np.around(slope,5),np.around(intercept,5))+'\n'+'R$^2$=%s'%(np.around(R,5)),
             fontsize=8)
if intercept<0:
    plt.text(min_B*1.2,(intercept+slope*max_B)*0.8,
             'y=%s*x%s'%(np.around(slope,5),np.around(intercept,5))+'\n'+'R$^2$=%s'%(np.around(R,5)),
             fontsize=8)
plt.plot(B_x,B_y,'-',linewidth = 1.5)
plt.tick_params(labelsize=8,pad=0.01)
plt.tick_params(font_keys)
plt.title('F',font_title,x=0,y=1)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.subplot(3,3,7)
plt.xlabel('chroma coordinate Z value',font_title,labelpad=0)
plt.ylabel('circadian factor',font_title,labelpad=0)
plt.plot(Z,circadian_factor,'*',linewidth = 1.5,markersize = 8)
plt.tick_params(labelsize=8,pad=0.01)
min_Z = min(Z)
max_Z = max(Z)
Z_x = np.arange(min_Z,max_Z,(max_Z-min_Z)/100)
slope,intercept,R,P,std_err = stats.linregress(Z,circadian_factor)
Z_y = np.array([intercept+slope*x for x in Z_x])
if intercept>0:
    plt.text(min_Z*1.2,(intercept+slope*max_Z)*0.8,
             'y=%s*x+%s'%(np.around(slope,5),np.around(intercept,5))+'\n'+'R$^2$=%s'%(np.around(R,5)),
             fontsize=8)
if intercept<0:
    plt.text(min_Z*1.2,(intercept+slope*max_Z)*0.8,
             'y=%s*x%s'%(np.around(slope,5),np.around(intercept,5))+'\n'+'R$^2$=%s'%(np.around(R,5)),
             fontsize=8)
plt.plot(Z_x,Z_y,'-',linewidth = 1.5)

plt.tick_params(font_keys)
plt.title('G',font_title,x=0,y=1)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.subplot(3,3,8)
plt.xlabel('correlated color temperature(K)',font_title,labelpad=0)
plt.ylabel('circadian factor',font_title,labelpad=0)
plt.plot(CCT,circadian_factor,'*',linewidth = 1.5,markersize = 8)
plt.tick_params(labelsize=8,pad=0.01)
min_CCT = min(CCT)
max_CCT = max(CCT)
CCT_x = np.arange(min_CCT,max_CCT,(max_CCT-min_CCT)/100)
slope,intercept,R,P,std_err = stats.linregress(CCT,circadian_factor)
CCT_y = np.array([intercept+slope*x for x in CCT_x])
if intercept>0:
    plt.text(min_CCT*1,(intercept+slope*max_CCT)*0.8,
             'y=%s*x+%s'%(np.around(slope,5),np.around(intercept,5))+'\n'+'R$^2$=%s'%(np.around(R,5)),
             fontsize=8)
if intercept<0:
    plt.text(min_CCT*1,(intercept+slope*max_CCT)*0.8,
             'y=%s*x%s'%(np.around(slope,5),np.around(intercept,5))+'\n'+'R$^2$=%s'%(np.around(R,5)),
             fontsize=8)
plt.plot(CCT_x,CCT_y,'-',linewidth = 1.5)

plt.tick_params(font_keys)
plt.title('H',font_title,x=0,y=1)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.subplot(3,3,9)
plt.xlabel('blue light ratio(%)',font_title,labelpad=0)
plt.ylabel('circadian factor',font_title,labelpad=0)
plt.plot(blue_light_ratio,circadian_factor,'*',linewidth = 1.5,markersize = 8)
plt.tick_params(labelsize=8,pad=0.01)
min_B = min(blue_light_ratio)
max_B = max(blue_light_ratio)
B_x = np.arange(min_B,max_B,(max_B-min_B)/100)
slope,intercept,R,P,std_err = stats.linregress(blue_light_ratio,circadian_factor)
B_y = np.array([intercept+slope*x for x in B_x])
if intercept>0:
    plt.text(min_B*1.2,(intercept+slope*max_B)*0.8,
             'y=%s*x+%s'%(np.around(slope,5),np.around(intercept,5))+'\n'+'R$^2$=%s'%(np.around(R,5)),fontsize=8)
if intercept<0:
    plt.text(min_B*1.2,(intercept+slope*max_B)*0.8,
             'y=%s*x%s'%(np.around(slope,5),np.around(intercept,5))+'\n'+'R$^2$=%s'%(np.around(R,5)),fontsize=8)
plt.plot(B_x,B_y,'-',linewidth = 1.5)

plt.tick_params(font_keys)
plt.title('I',font_title,x=0,y=1)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')


plt.tight_layout()
plt.subplots_adjust(wspace=0.3,hspace=0.4)
plt.savefig(picture_path+'Figure4.tiff',dpi=dpi2,bbox_inches='tight')
plt.show()
